# %% [markdown]
# # Análisis Exploratorio de Datos
#
# 1. Objetivos:
# - Aprender las herramientas básicas para darle un primer vistazo a los datos que tenemos en nuestros `DataFrames`
#
# ---
#
# 2. Desarrollo:

# %%
import pandas as pd
import json

# %% [markdown]
# Ok, tenemos aquí nuestro conjunto de datos del Ejemplo pasado:

# %%
f = open('../Datasets/zomato_reviews-clean.json', 'r')
json_data = json.load(f)
f.close()

# %%
df = pd.DataFrame.from_dict(json_data)
df
# Out:
#       has_online_delivery  price_range currency                        name  \
# 0                       1            3      Rs.            Hauz Khas Social
# 1                       0            3      Rs.  Qubitos - The Terrace Cafe
# 2                       1            2      Rs.             The Hudson Cafe
# 3                       0            3      Rs.           Summer House Cafe
# 4                       0            3      Rs.                 38 Barracks
# ...                   ...          ...      ...                         ...
# 1175                    0            3        £               The Boozy Cow
# 1176                    0            3        £                 La Favorita
# 1177                    0            3        £           Roseleaf Bar Cafe
# 1178                    0            3        £                   Civerinos
# 1179                    0            3        £             The Hanging Bat
#
#                                                cuisines  \
# 0            Continental, American, Asian, North Indian
# 1     Thai, European, Mexican, North Indian, Chinese...
# 2                   Cafe, Italian, Continental, Chinese
# 3                                  Italian, Continental
# 4                North Indian, Italian, Asian, American
# ...                                                 ...
# 1175                                      Burger, Grill
# 1176                                            Italian
# 1177                                     Scottish, Cafe
# 1178                                     Pizza, Italian
# 1179                                           American
#
#                                        location.address location.city  \
# 0                9-A & 12, Hauz Khas Village, New Delhi     New Delhi
# 1     C-7, Vishal Enclave, Opposite Metro Pillar 417...     New Delhi
# 2     2524, 1st Floor, Hudson Lane, Delhi University...     New Delhi
# 3     1st Floor, DDA Shopping Complex, Aurobindo Pla...     New Delhi
# 4        M-38, Outer Circle, Connaught Place, New Delhi     New Delhi
# ...                                                 ...           ...
# 1175   17 Frederick Street, New Town, Edinburgh EH2 2EY     Edinburgh
# 1176       325-331 Leith Walk, Leith, Edinburgh EH6 8SA     Edinburgh
# 1177     23-24 Sandport Place, Leith, Edinburgh EH6 6EW     Edinburgh
# 1178  5 Hunter Square, Royal Mile, Old Town, Edinbur...     Edinburgh
# 1179      133 Lothian Road, Old Town, Edinburgh EH3 9AD     Edinburgh
#
#      user_rating.rating_text
# 0                  Very Good
# 1                  Excellent
# 2                  Very Good
# 3                  Very Good
# 4                  Very Good
# ...                      ...
# 1175               Very Good
# 1176               Excellent
# 1177               Excellent
# 1178                    Good
# 1179                    Good
#
# [1180 rows x 8 columns]

# %% [markdown]
# Podemos saber la forma de nuestro DataFrame accediendo a la propiedad shape. El primer valor es el número de filas, mientras que el segundo es el número de columnas:

# %% [markdown]
# Pasos para el dataset en equipo:

# %%
df.shape
# Out:
# (1180, 8)

# %% [markdown]
# Podemos ver un número determinado de filas comenzando desde el principio con head:

# %% [markdown]
# Muestra las 5 primeras

# %%
df.head(5)
# Out:
#    has_online_delivery  price_range currency                        name  \
# 0                    1            3      Rs.            Hauz Khas Social
# 1                    0            3      Rs.  Qubitos - The Terrace Cafe
# 2                    1            2      Rs.             The Hudson Cafe
# 3                    0            3      Rs.           Summer House Cafe
# 4                    0            3      Rs.                 38 Barracks
#
#                                             cuisines  \
# 0         Continental, American, Asian, North Indian
# 1  Thai, European, Mexican, North Indian, Chinese...
# 2                Cafe, Italian, Continental, Chinese
# 3                               Italian, Continental
# 4             North Indian, Italian, Asian, American
#
#                                     location.address location.city  \
# 0             9-A & 12, Hauz Khas Village, New Delhi     New Delhi
# 1  C-7, Vishal Enclave, Opposite Metro Pillar 417...     New Delhi
# 2  2524, 1st Floor, Hudson Lane, Delhi University...     New Delhi
# 3  1st Floor, DDA Shopping Complex, Aurobindo Pla...     New Delhi
# 4     M-38, Outer Circle, Connaught Place, New Delhi     New Delhi
#
#   user_rating.rating_text
# 0               Very Good
# 1               Excellent
# 2               Very Good
# 3               Very Good
# 4               Very Good

# %%
df.head(20)
# Out:
#     has_online_delivery  price_range currency  \
# 0                     1            3      Rs.
# 1                     0            3      Rs.
# 2                     1            2      Rs.
# 3                     0            3      Rs.
# 4                     0            3      Rs.
# 5                     1            2      Rs.
# 6                     0            4      Rs.
# 7                     0            4      Rs.
# 8                     0            4      Rs.
# 9                     1            3      Rs.
# 10                    0            2      Rs.
# 11                    0            4      Rs.
# 12                    0            3      Rs.
# 13                    1            3      Rs.
# 14                    0            3      Rs.
# 15                    0            3      Rs.
# 16                    0            3      Rs.
# 17                    0            3      Rs.
# 18                    1            2      Rs.
# 19                    0            3      Rs.
#
#                                 name  \
# 0                   Hauz Khas Social
# 1         Qubitos - The Terrace Cafe
# 2                    The Hudson Cafe
# 3                  Summer House Cafe
# 4                        38 Barracks
# 5                      Spezia Bistro
# 6   Manhattan Brewery & Bar Exchange
# 7                   The Wine Company
# 8                         Farzi Cafe
# 9                  Indian Grill Room
# 10                   Cafeteria & Co.
# 11                        Farzi Cafe
# 12                  Molecule Air Bar
# 13                           HotMess
# 14               My Bar Headquarters
# 15                          FLYP@MTV
# 16                           Tamasha
# 17              The Barbeque Company
# 18                   Saravana Bhavan
# 19                      Odeon Social
#
#                                              cuisines  \
# 0          Continental, American, Asian, North Indian
# 1   Thai, European, Mexican, North Indian, Chinese...
# 2                 Cafe, Italian, Continental, Chinese
# 3                                Italian, Continental
# 4              North Indian, Italian, Asian, American
# 5                 Cafe, Continental, Chinese, Italian
# 6   Finger Food, American, Continental, North Indi...
# 7                                   Italian, European
# 8                                       Modern Indian
# 9                               North Indian, Mughlai
# 10                               Continental, Mexican
# 11                                      Modern Indian
# 12        Continental, North Indian, Italian, Chinese
# 13      North Indian, Mediterranean, Asian, Fast Food
# 14                     North Indian, Mughlai, Chinese
# 15        North Indian, Mexican, Italian, Continental
# 16    Finger Food, North Indian, Continental, Italian
# 17                 North Indian, Chinese, Continental
# 18                                       South Indian
# 19         Continental, American, Asian, North Indian
#
#                                      location.address location.city  \
# 0              9-A & 12, Hauz Khas Village, New Delhi     New Delhi
# 1   C-7, Vishal Enclave, Opposite Metro Pillar 417...     New Delhi
# 2   2524, 1st Floor, Hudson Lane, Delhi University...     New Delhi
# 3   1st Floor, DDA Shopping Complex, Aurobindo Pla...     New Delhi
# 4      M-38, Outer Circle, Connaught Place, New Delhi     New Delhi
# 5   2525, 1st Floor, Hudson Lane, Delhi University...     New Delhi
# 6   1st Floor, Global Foyer Mall, Sector 43, Golf ...       Gurgaon
# 7                  Cyber Hub, DLF Cyber City, Gurgaon       Gurgaon
# 8   38/39, Level 1, Block E , Inner Circle, Connau...     New Delhi
# 9   315, 3rd Floor, Suncity Business Tower, Golf C...       Gurgaon
# 10          G 14, Hudson Lane, Vijay Nagar, New Delhi     New Delhi
# 11  7-8, Ground Floor, Cyber Hub, DLF Cyber City, ...       Gurgaon
# 12  4th Floor, SCO 53, Main Market, Sector 29, Gur...       Gurgaon
# 13    M-11, Middle Circle, Connaught Place, New Delhi     New Delhi
# 14        N-49, 2nd Floor, Connaught Place, New Delhi     New Delhi
# 15  N/57 & N/60, 1st Floor, Outer Circle, Connaugh...     New Delhi
# 16  28, Kasturba Gandhi Marg, Connaught Place, New...     New Delhi
# 17              HL 1-2, L Block, Jail Road, New Delhi     New Delhi
# 18  P-13, Connaught Circus, Connaught Place, New D...     New Delhi
# 19  1st Floor, 23, Odeon Building, Radial 5, D Blo...     New Delhi
#
#    user_rating.rating_text
# 0                Very Good
# 1                Excellent
# 2                Very Good
# 3                Very Good
# 4                Very Good
# 5                Excellent
# 6                Excellent
# 7                     Poor
# 8                Very Good
# 9                Excellent
# 10               Excellent
# 11               Very Good
# 12               Very Good
# 13               Very Good
# 14                    Good
# 15                    Good
# 16                    Good
# 17               Very Good
# 18               Very Good
# 19               Very Good

# %% [markdown]
# Muestra las 5 ultimas

# %%
df.tail()
# Out:
#       has_online_delivery  price_range currency               name  \
# 1175                    0            3        £      The Boozy Cow
# 1176                    0            3        £        La Favorita
# 1177                    0            3        £  Roseleaf Bar Cafe
# 1178                    0            3        £          Civerinos
# 1179                    0            3        £    The Hanging Bat
#
#             cuisines                                   location.address  \
# 1175   Burger, Grill   17 Frederick Street, New Town, Edinburgh EH2 2EY
# 1176         Italian       325-331 Leith Walk, Leith, Edinburgh EH6 8SA
# 1177  Scottish, Cafe     23-24 Sandport Place, Leith, Edinburgh EH6 6EW
# 1178  Pizza, Italian  5 Hunter Square, Royal Mile, Old Town, Edinbur...
# 1179        American      133 Lothian Road, Old Town, Edinburgh EH3 9AD
#
#      location.city user_rating.rating_text
# 1175     Edinburgh               Very Good
# 1176     Edinburgh               Excellent
# 1177     Edinburgh               Excellent
# 1178     Edinburgh                    Good
# 1179     Edinburgh                    Good

# %%
df.tail(10)
# Out:
#       has_online_delivery  price_range currency  \
# 1170                    0            2        £
# 1171                    0            4        £
# 1172                    0            4        £
# 1173                    0            2        £
# 1174                    0            4        £
# 1175                    0            3        £
# 1176                    0            3        £
# 1177                    0            3        £
# 1178                    0            3        £
# 1179                    0            3        £
#
#                                   name                    cuisines  \
# 1170        Tuk Tuk Indian Street Food         Indian, Street Food
# 1171                        Chaophraya                        Thai
# 1172                             Steak    Steak, Scottish, British
# 1173                           Bentoya  Sushi, Japanese, Cantonese
# 1174  The Witchery & The Secret Garden  British, Scottish, Seafood
# 1175                     The Boozy Cow               Burger, Grill
# 1176                       La Favorita                     Italian
# 1177                 Roseleaf Bar Cafe              Scottish, Cafe
# 1178                         Civerinos              Pizza, Italian
# 1179                   The Hanging Bat                    American
#
#                                        location.address location.city  \
# 1170       1 Leven Street, Tollcross, Edinburgh EH3 9NB     Edinburgh
# 1171  4th Floor, 33 Castle Street, New Town, Edinbur...     Edinburgh
# 1172      14 Picardy Place, New Town, Edinburgh EH1 3JT     Edinburgh
# 1173       15 Bread Street, Old Town, Edinburgh EH3 9AL     Edinburgh
# 1174  Castlehill, The Royal Mile, Old Town, Edinburg...     Edinburgh
# 1175   17 Frederick Street, New Town, Edinburgh EH2 2EY     Edinburgh
# 1176       325-331 Leith Walk, Leith, Edinburgh EH6 8SA     Edinburgh
# 1177     23-24 Sandport Place, Leith, Edinburgh EH6 6EW     Edinburgh
# 1178  5 Hunter Square, Royal Mile, Old Town, Edinbur...     Edinburgh
# 1179      133 Lothian Road, Old Town, Edinburgh EH3 9AD     Edinburgh
#
#      user_rating.rating_text
# 1170               Very Good
# 1171               Very Good
# 1172               Very Good
# 1173                    Good
# 1174               Very Good
# 1175               Very Good
# 1176               Excellent
# 1177               Excellent
# 1178                    Good
# 1179                    Good

# %% [markdown]
# Podemos ver también las filas del final con tail:

# %% [markdown]
# Podemos ver los dtypes de todas nuestras columnas accediendo a esa propiedad:

# %% [markdown]
# Tipos de datos contiene la base de datos

# %%
df.dtypes
# Out:
# has_online_delivery         int64
# price_range                 int64
# currency                   object
# name                       object
# cuisines                   object
# location.address           object
# location.city              object
# user_rating.rating_text    object
# dtype: object

# %% [markdown]
# También podemos usar la función info del DataFrame para ver más información sobre las columnas. Por ejemplo, el número de valores no nulos que hay en cada una.

# %% [markdown]
# Para saber cuantos valores nulos de la base de datos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1180 entries, 0 to 1179
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   has_online_delivery      1180 non-null   int64
#  1   price_range              1180 non-null   int64
#  2   currency                 1180 non-null   object
#  3   name                     1180 non-null   object
#  4   cuisines                 1180 non-null   object
#  5   location.address         1180 non-null   object
#  6   location.city            1180 non-null   object
#  7   user_rating.rating_text  1180 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 83.0+ KB

# %% [markdown]
# Pone en una tabla la descripcion general

# %%
df.describe()
# Out:
#        has_online_delivery  price_range
# count          1180.000000  1180.000000
# mean              0.112712     2.827119
# std               0.316374     0.863319
# min               0.000000     1.000000
# 25%               0.000000     2.000000
# 50%               0.000000     3.000000
# 75%               0.000000     3.000000
# max               1.000000     4.000000

# %% [markdown]
# En caso de que tengamos tantas columnas que no podamos verlas todas en el preview de arriba, podemos acceder a una lista de columnas usando las propiedad columns:

# %% [markdown]
# Para saber el nombre de las columnas

# %%
df.columns
# Out:
# Index(['has_online_delivery', 'price_range', 'currency', 'name', 'cuisines',
#        'location.address', 'location.city', 'user_rating.rating_text'],
#       dtype='object')

# %% [markdown]
# Vamos a un Reto para que puedas practicar leer un conjunto de datos y hacer una exploración básica.
